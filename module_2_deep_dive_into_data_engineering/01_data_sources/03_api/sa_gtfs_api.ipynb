# %%
import requests
import os
from io import BytesIO
from zipfile import ZipFile

# %%
# Official page: https://gtfs.adelaidemetro.com.au/
# URLs
base_url = "http://gtfs.adelaidemetro.com.au/v1"
latest_version_number = "static/latest/version.txt"
latest_version_feed = "static/latest/google_transit.zip"

# binary data as response
request_headers={"Content-Type": "application/octet-stream"}

# Feed template
# practice: how to use string template + format
feed_url_template = "static/{version}/google_transit.zip"

# output
dest_path = 'destination'
os.makedirs(dest_path, exist_ok=True)

# %%
latest_version_number_url = f"{base_url}/{latest_version_number}"
latest_version_number_url
# Out:
# 'http://gtfs.adelaidemetro.com.au/v1/static/latest/version.txt'

# %%
resp = requests.get(latest_version_number_url)
resp
#resp.__dict__
# Out:
# <Response [200]>

# %%
resp.__dict__
# Out:
# {'_content': b'1605',
#  '_content_consumed': True,
#  '_next': None,
#  'status_code': 200,
#  'headers': {'Content-Type': 'binary/octet-stream', 'Content-Length': '4', 'Connection': 'keep-alive', 'Date': 'Thu, 11 Dec 2025 09:42:24 GMT', 'Last-Modified': 'Thu, 11 Dec 2025 05:23:03 GMT', 'ETag': '"f18a6d1cde4b205199de8729a6637b42"', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': '9TtDtlMSIcPBQTMGeyHmbtR4IuMrp_4u', 'Accept-Ranges': 'bytes', 'Server': 'AmazonS3', 'X-Cache': 'Miss from cloudfront', 'Via': '1.1 c208b48fbec10c0f1f0b58f7fa79fbfc.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SYD3-P3', 'X-Amz-Cf-Id': 'ru4DUOGWYt1XtMBDV8oTHYi7UymgJtR0Pt22-zYiiukoLotvy4I_Tw=='},
#  'raw': <urllib3.response.HTTPResponse at 0x1e1467b9c60>,
#  'url': 'https://gtfs.adelaidemetro.com.au/v1/static/latest/version.txt',
#  'encoding': None,
#  'history': [<Response [301]>],
#  'reason': 'OK',
#  'cookies': <RequestsCookieJar[]>,
#  'elapsed': datetime.timedelta(microseconds=420754),
#  'request': <PreparedRequest [GET]>,
#  'connection': <requests.adapters.HTTPAdapter at 0x1e1467ba1e0>}

# %%
resp.content
# Out:
# b'1605'

# %% [markdown]
# Read latest version

# %%
# 1. Find the latest feed version
# 2. Download latest GTFS feed version using request
# # Feed's URL

# %% [markdown]
# Dynamic read multiple feed versions: 930 to 939

# %%
# HINTS
# 1. For loop the versions
# 2. Generate versioned URL
# 3. Request and handle response
for version in range(930, 940):
    print("Version")

# %% [markdown]
# Unzip feed versions & export files

# %%
# # using ZipFile to read zipfile
# # then extract all

# # Define the path to your zip file
# zip_file_path = 'destination/latest.zip' 

# # Define the directory where you want to extract the files (optional)
# # If not specified, files will be extracted to the current working directory
# extract_to_path = 'destination/latest/' 

# with ZipFile(zip_file_path, 'r') as zip_obj:
#     # Extract all files to the specified directory
#     zip_obj.extractall(extract_to_path)

# %% [markdown]
# Extra: extract zipfile from response.content

# %%
# HINTS
# Use BytesIO (file bytes in memory) + ZipFile
